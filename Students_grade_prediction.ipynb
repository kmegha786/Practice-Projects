# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\HRIDVI ARORA\Downloads\Grades.csv")

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.tail()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# ...

# %%
df.shape
# Out:
# (571, 43)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %% [markdown]
# It can be seen that most of the columns have missing values.

# %%
for column in df:
    df[column]=df[column].fillna(df[column].mode()[0])

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %%
df['PH-121'].unique()
# Out:
# array(['B-', 'A', 'D', 'A-', 'B+', 'B', 'C+', 'C', 'C-', 'D+', 'WU', 'A+',
#        'F'], dtype=object)

# %%
df['CS-317'].unique()
# Out:
# array(['C-', 'D', 'B', 'C', 'B+', 'B-', 'A-', 'D+', 'C+', 'A', 'A+', 'F'],
#       dtype=object)

# %%
df['TC-383'].unique()
# Out:
# array(['C+', 'C-', 'B', 'D+', 'C', 'B+', 'B-', 'D', 'A-', 'A', 'F', 'A+'],
#       dtype=object)

# %%
df['CS-412'].unique()
# Out:
# array(['A-', 'B', 'A', 'C+', 'B+', 'C-', 'B-', 'A+', 'C', 'D+', 'F', 'W',
#        'D'], dtype=object)

# %%
df['EE-217'].unique()
# Out:
# array(['A', 'B-', 'D+', 'A-', 'A+', 'C', 'B+', 'B', 'C-', 'D', 'WU', 'F',
#        'C+'], dtype=object)

# %%
df['CS-406'].unique()
# Out:
# array(['A-', 'A', 'B-', 'B', 'B+', 'C+', 'D', 'D+', 'C-', 'C', 'A+', 'F',
#        'W', 'WU'], dtype=object)

# %%
df = df.replace(['WU','W','I'],'F')

# %%
df['CS-406'].unique()
# Out:
# array(['A-', 'A', 'B-', 'B', 'B+', 'C+', 'D', 'D+', 'C-', 'C', 'A+', 'F'],
#       dtype=object)

# %% [markdown]
# #  Encoding Categorical Columns

# %%
grades = ['A','A+','A-','B','B+','B-','C+','C','C-','D','D+','F']

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder(categories=[grades])

# %%
df1 = df.drop(columns=['Seat No.','CGPA'],axis=1)

# %%
df=df.drop(columns=['Seat No.'],axis=1)
df
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df.head()
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0     5.0    10.0     8.0        7.0     8.0    10.0     9.0     8.0     5.0
# 1     0.0     9.0    10.0        9.0     5.0     7.0     9.0     0.0    10.0
# 2     0.0     3.0     0.0        5.0     4.0     0.0     5.0     4.0     2.0
# 3     9.0     6.0    10.0        9.0     9.0     2.0    10.0     8.0     9.0
# 4     2.0     2.0     2.0        4.0     0.0     0.0     2.0     4.0     0.0
#
#    ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  CS-419  \
# 0     8.0  ...     8.0     8.0     8.0     8.0     2.0     0.0     8.0
# 1     9.0  ...    10.0     9.0     7.0     9.0     2.0     5.0     7.0
# 2     2.0  ...     3.0     3.0     0.0     7.0     0.0     0.0     0.0
# 3     6.0  ...    10.0     7.0    10.0     8.0     5.0     3.0     6.0
# 4     2.0  ...     5.0     4.0     4.0     5.0     2.0     0.0     2.0
#
#    CS-423  CS-412   CGPA
# 0     3.0     2.0  2.205
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Data Visualization of Categorical columns.

# %%
plt.figure(figsize=(80,75))
plotnumber=1

for column in df[1:]:
    if plotnumber<=42:
        ax=plt.subplot(5,9,plotnumber)
        sns.countplot(x=column,data=df[1:])
    plotnumber=plotnumber+1

plt.show()

# %% [markdown]
# Data Visualization of Continuous Column.

# %%
sns.distplot(df['CGPA'],kde=True)
# Out:
# <AxesSubplot:xlabel='CGPA', ylabel='Density'>

# %% [markdown]
# # Checking for Skewness

# %%
df.skew().sort_values()
# Out:
# CGPA        -0.497203
# CS-214      -0.040462
# HS-101       0.023442
# ME-107       0.082120
# CS-211       0.119231
# CS-317       0.123093
# CS-215       0.145310
# CS-421       0.153287
# MT-222       0.173050
# EF-303       0.266661
# CS-318       0.269861
# CS-203       0.300804
# HS-105/12    0.310444
# TC-383       0.333888
# CS-107       0.387904
# CS-212       0.401475
# CS-301       0.410063
# CS-312       0.413220
# CS-306       0.414987
# MT-224       0.420920
# EL-332       0.437624
# MT-111       0.465304
# HS-304       0.473627
# EL-102       0.486122
# CS-419       0.510835
# CS-423       0.519273
# PH-121       0.532631
# EE-119       0.563273
# CS-302       0.604224
# CS-403       0.617339
# MT-331       0.626528
# CS-106       0.656070
# CS-210       0.684884
# EE-217       0.705923
# EE-222       0.731743
# MT-442       0.869952
# HS-205/20    0.876517
# CS-105       0.931557
# CY-105       0.954778
# CS-414       1.260980
# CS-412       1.285380
# ...

# %%
plt.figure(figsize=(25,20))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor='black',fmt='.2f')
plt.title("Correlation matrix")
plt.show()

# %%
df.corr()['CGPA'].sort_values()
# Out:
# CS-317      -0.773785
# CS-210      -0.769264
# CS-214      -0.751620
# CS-215      -0.739897
# EL-332      -0.735837
# MT-111      -0.731303
# CS-306      -0.715802
# CS-302      -0.698382
# MT-224      -0.689211
# CS-301      -0.673111
# PH-121      -0.668606
# ME-107      -0.667114
# EE-217      -0.663206
# CY-105      -0.662748
# EE-119      -0.661298
# MT-222      -0.656733
# CS-212      -0.655517
# CS-203      -0.649492
# CS-421      -0.649246
# CS-419      -0.647957
# EL-102      -0.639762
# HS-105/12   -0.625465
# CS-211      -0.625136
# CS-107      -0.618076
# CS-105      -0.612860
# MT-442      -0.583758
# EE-222      -0.575016
# TC-383      -0.571899
# CS-318      -0.569148
# HS-304      -0.569047
# CS-403      -0.550708
# HS-101      -0.539407
# CS-106      -0.534604
# CS-423      -0.531322
# MT-331      -0.506450
# EF-303      -0.506398
# CS-406      -0.479491
# CS-412      -0.473554
# CS-312      -0.466549
# HS-205/20   -0.460923
# CS-414      -0.393012
# ...

# %% [markdown]
# From the above observation it can be inferred that all the features have negative relation with the target variable.
# CS-317 has highest relationship(79%). Whereas, CS-414 has lowest relationship(40%)

# %% [markdown]
# # Plotting Bar graph to check the correlation with target

# %%
plt.figure(figsize=(22,7))
df.corr()['CGPA'].sort_values(ascending=False).drop(['CGPA']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=18)
plt.title('Correlation')
plt.show()

# %% [markdown]
# Checking for outliers

# %%
#Plotting boxplot for first 20 columns
df.iloc[:,0:20].boxplot(figsize=[20,18])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
#Plotting boxplot for remaining columns
df.iloc[:20:].boxplot(figsize=[20,18])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# # Training our model

# %% [markdown]
# Separating features and label as x and y

# %%
x=df.drop(columns=['CGPA'],axis=1)
y=df['CGPA']

# %% [markdown]
# # Data Standardisation

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

x_scaled=scaler.fit_transform(x)

# %% [markdown]
# # Check for Multicolliernity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['vif1']=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif['features']=x.columns
vif
# Out:
#         vif1   features
# 0   2.914191     PH-121
# 1   1.808338     HS-101
# 2   2.604379     CY-105
# 3   2.310841  HS-105/12
# 4   2.630644     MT-111
# 5   2.380660     CS-105
# 6   1.940681     CS-106
# 7   1.975682     EL-102
# 8   2.317884     EE-119
# 9   2.377481     ME-107
# 10  2.354220     CS-107
# 11  1.645965  HS-205/20
# 12  2.316385     MT-222
# 13  2.320618     EE-222
# 14  2.893962     MT-224
# 15  3.254189     CS-210
# 16  2.699695     CS-211
# 17  2.678293     CS-203
# 18  2.825933     CS-214
# 19  2.524468     EE-217
# 20  2.879741     CS-212
# 21  3.184816     CS-215
# 22  2.057689     MT-331
# 23  2.331289     EF-303
# 24  2.633975     HS-304
# 25  3.131744     CS-301
# 26  2.774771     CS-302
# 27  2.947071     TC-383
# 28  2.064531     MT-442
# 29  3.394348     EL-332
# 30  2.414955     CS-318
# 31  3.742623     CS-306
# 32  3.308888     CS-312
# 33  3.391855     CS-317
# 34  2.587711     CS-403
# 35  2.902514     CS-421
# 36  2.171569     CS-406
# ...

# %% [markdown]
# Variance Inflation Factor is less than 5 for all columns so there is no multicollinearity

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,accuracy_score
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
lr=LinearRegression()

# %% [markdown]
# # Finding the best random state

# %%
max_acc=0
max_rs=0

for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,random_state=i,test_size=0.20)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred_lr=lr.predict(x_test)
    accuracy=r2_score(y_test,pred_lr)
    print('Testing accuracy', accuracy,'random state',i)
    
    if accuracy>max_acc:
        max_acc=accuracy
        max_rs=i
        print('max_accuracy',max_acc,'max_random_state',i)
# Out:
# Testing accuracy 0.9507257930169589 random state 0
# max_accuracy 0.9507257930169589 max_random_state 0
# Testing accuracy 0.9494571621096087 random state 1
# Testing accuracy 0.9441652784592088 random state 2
# Testing accuracy 0.9418446728289375 random state 3
# Testing accuracy 0.9454200834340655 random state 4
# Testing accuracy 0.9234524385925735 random state 5
# Testing accuracy 0.9581279998632354 random state 6
# max_accuracy 0.9581279998632354 max_random_state 6
# Testing accuracy 0.963966125145452 random state 7
# max_accuracy 0.963966125145452 max_random_state 7
# Testing accuracy 0.91576360002336 random state 8
# Testing accuracy 0.8469194707699146 random state 9
# Testing accuracy 0.9532334315517637 random state 10
# Testing accuracy 0.7645943042429882 random state 11
# Testing accuracy 0.9234718261459376 random state 12
# Testing accuracy 0.9102936806488477 random state 13
# Testing accuracy 0.7923296800081343 random state 14
# ...

# %% [markdown]
# # Train Test Split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)

# %% [markdown]
# # Linear Regression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred=lr.predict(x_train)
print(r2_score(y_train,y_train_pred))
# Out:
# 0.9219475815341156

# %%
pred_test_y=lr.predict(x_test)

print(r2_score(y_test,pred_test_y))
# Out:
# 0.9710989124490972

# %% [markdown]
# # Using Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

rf.fit(x_train,y_train)

pred_test_y=rf.predict(x_test)
print("Testing Accuracy",r2_score(y_test,pred_test_y))
# Out:
# Testing Accuracy 0.9525532335860003
