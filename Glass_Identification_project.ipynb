# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\HRIDVI ARORA\Downloads\glass.csv")

# %%
df.head()
# Out:
#    1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0  2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00    1
# 1  3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00    1
# 2  4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00    1
# 3  5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00    1
# 4  6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26    1

# %%
df.tail()
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 208  210  1.51623  14.14   0.0  2.88  72.61  0.08  9.18  1.06     0.0    7
# 209  211  1.51685  14.92   0.0  1.99  73.06  0.00  8.40  1.59     0.0    7
# 210  212  1.52065  14.36   0.0  2.02  73.42  0.00  8.44  1.64     0.0    7
# 211  213  1.51651  14.38   0.0  1.94  73.61  0.00  8.48  1.57     0.0    7
# 212  214  1.51711  14.23   0.0  2.08  73.36  0.00  8.62  1.67     0.0    7

# %%
df.shape
# Out:
# (213, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   1        213 non-null    int64
#  1   1.52101  213 non-null    float64
#  2   13.64    213 non-null    float64
#  3   4.49     213 non-null    float64
#  4   1.10     213 non-null    float64
#  5   71.78    213 non-null    float64
#  6   0.06     213 non-null    float64
#  7   8.75     213 non-null    float64
#  8   0.00     213 non-null    float64
#  9   0.00.1   213 non-null    float64
#  10  1.1      213 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.4 KB

# %%
df.isnull().sum()
# Out:
# 1          0
# 1.52101    0
# 13.64      0
# 4.49       0
# 1.10       0
# 71.78      0
# 0.06       0
# 8.75       0
# 0.00       0
# 0.00.1     0
# 1.1        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                 1     1.52101       13.64        4.49        1.10       71.78  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean   108.000000    1.518353   13.406761    2.676056    1.446526   72.655023
# std     61.631972    0.003039    0.818371    1.440453    0.499882    0.774052
# min      2.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     55.000000    1.516520   12.900000    2.090000    1.190000   72.280000
# 50%    108.000000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    161.000000    1.519150   13.830000    3.600000    1.630000   73.090000
# max    214.000000    1.533930   17.380000    3.980000    3.500000   75.410000
#
#              0.06        8.75        0.00      0.00.1         1.1
# count  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     0.499108    8.957934    0.175869    0.057277    2.788732
# std      0.653035    1.426435    0.498245    0.097589    2.105130
# ...

# %%
# Adding attribute names
names = ['ID','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Glass_type']
df.columns = names

# %%
df
# Out:
#       ID       RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  \
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...   ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.00
#
#      Glass_type
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 208           7
# ...

# %% [markdown]
# Removing unnecessary columns

# %%
df = df.drop('ID',axis=1)

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  Glass_type
# 0  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00           1
# 1  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00           1
# 2  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00           1
# 3  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00           1
# 4  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26           1

# %% [markdown]
# # Checking outliers

# %%
from scipy import stats

z = abs(stats.zscore(df))
#np.where(z > 3)
df = df[(z < 3).all(axis=1)]

# %% [markdown]
# # Seperating features and label

# %%
features = ['RI','Mg','Na','Al','Si','K','Ca','Ba','Fe']
label = ['Glass_type']

X = df[features]
Y = df[label]

# %%
X.shape
# Out:
# (193, 9)

# %% [markdown]
# # Data Visualization

# %%
x1 = X.values
for i in range(0,8):
    sns.distplot(x1[i])
    plt.xlabel(features[i])
    plt.show()

# %% [markdown]
# It is observed that the data is not normalized, it is skewed to either positive side or negative side.

# %%
x1 = pd.DataFrame(X)
plt.figure(figsize=(8,8))
sns.pairplot(data=x1)
plt.show()

# %%
coreleation= X.corr()
plt.figure(figsize=(10,10))
sns.heatmap(coreleation,cbar=True,square=True,annot=True,fmt='.1f',annot_kws={'size': 15},xticklabels=features,yticklabels=features,alpha=0.7,cmap= 'coolwarm')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
#scaler.fit(X)
#X = scaler.transform(X)
#X = pd.DataFrame(X)

# %%
X.head(2)
# Out:
#         RI    Mg     Na    Al     Si     K    Ca   Ba   Fe
# 0  1.51761  3.60  13.89  1.36  72.73  0.48  7.83  0.0  0.0
# 1  1.51618  3.55  13.53  1.54  72.99  0.39  7.78  0.0  0.0

# %%
Y.head(2)
# Out:
#    Glass_type
# 0           1
# 1           1

# %%
from sklearn import preprocessing
X=preprocessing.scale(X)

# %%
x1 = X
for i in range(0,8):
    sns.distplot(x1[i])
    plt.xlabel(features[i])
    plt.show()

# %% [markdown]
# Skewness is reduced after preprocessing and data is more normalized.

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
## Flattening the array
Y_train = Y_train.values.ravel()
Y_test = Y_test.values.ravel()

# %%
print('Shape of X_train = ' + str(X_train.shape))
print('Shape of X_test = ' + str(X_test.shape))
print('Shape of Y_train = ' + str(Y_train.shape))
print('Shape of Y_test = ' + str(Y_test.shape))
# Out:
# Shape of X_train = (144, 9)
# Shape of X_test = (49, 9)
# Shape of Y_train = (144,)
# Shape of Y_test = (49,)

# %% [markdown]
# # Applying Different Machine learning Models

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

Scores = []

for i in range(1):
    tree = DecisionTreeClassifier(random_state=0)
    tree.fit(X_train, Y_train)
    score = tree.score(X_test,Y_test)
    Scores.append(score)

print(tree.score(X_train,Y_train))
print(Scores)
# Out:
# 1.0
# [0.6326530612244898]

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

Scores = []

for i in range(1):
    logistic = LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial',max_iter=100)
    logistic.fit(X_train, Y_train)
    score = logistic.score(X_test,Y_test)
    Scores.append(score)
    
print(logistic.score(X_train,Y_train))
print(Scores)
# Out:
# 0.7430555555555556
# [0.6530612244897959]

# %% [markdown]
# # KNN

# %%
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

Scores = []

for i in range (2,11):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, Y_train)
    score = knn.score(X_test,Y_test)
    Scores.append(score)

print(knn.score(X_train,Y_train))
print(Scores)
# Out:
# 0.6875
# [0.673469387755102, 0.6938775510204082, 0.7142857142857143, 0.6938775510204082, 0.6938775510204082, 0.673469387755102, 0.6122448979591837, 0.5918367346938775, 0.5714285714285714]
